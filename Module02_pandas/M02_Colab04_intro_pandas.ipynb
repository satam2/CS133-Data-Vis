# %% [markdown]
# ## **Working with Python DataFrame**
# In this activity we will be using a US Crime Rate dataset to look at different type of crime rates in different states between the years of 1960 to 2003. This notebook is an introduction to exploring tabular data using the pandas library
#
# ### **Learning outcome:**
# - To learn to examine tabular raw data with a pandas dataframe
# - To learn to filter data from a dataframe using index- or label-based selection.

# %%
# Importing libraries
import pandas as pd
pd.options.display.float_format = "{:,.2f}".format #Display only 2 decimals

# %%
# Read in data set and converting it to a pandas dataframe
crcol = ['state', 'year', 'pop', 'violent', 'murder', 'rape',
         'robbery', 'assault', 'property', 'burglary', 'larceny', 'vehicle']
crime_rates = pd.read_csv('https://raw.githubusercontent.com/csbfx/advpy122-data/master/crime_rates.csv', names=crcol, header=0)

# %%
# Let's take a look at the dataframe using head()

crime_rates.head()
# Out:
#     state  year     pop  violent  murder  rape  robbery  assault  property  \
# 0  Alaska  1960  226167   104.30   10.20 20.80    28.30    45.10  1,544.90
# 1  Alaska  1961  234000    88.90   11.50 13.20    12.40    51.70  1,540.60
# 2  Alaska  1962  246000    91.50    4.50 18.70    13.80    54.50  1,564.60
# 3  Alaska  1963  248000   109.70    6.50 14.90    22.20    66.10  1,952.80
# 4  Alaska  1964  250000   150.00   10.40 22.40    21.20    96.00  2,016.00
#
#    burglary  larceny  vehicle
# 0    332.10   970.50   242.30
# 1    380.80   950.00   209.80
# 2    351.60   985.40   227.60
# 3    381.50 1,213.70   357.70
# 4    443.60 1,218.40   354.00

# %%
### Summary of DataFrame using .info()

crime_rates.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     2200 non-null   str
#  1   year      2200 non-null   int64
#  2   pop       2200 non-null   int64
#  3   violent   2200 non-null   float64
#  4   murder    2200 non-null   float64
#  5   rape      2200 non-null   float64
#  6   robbery   2200 non-null   float64
#  7   assault   2200 non-null   float64
#  8   property  2200 non-null   float64
#  9   burglary  2200 non-null   float64
#  10  larceny   2200 non-null   float64
#  11  vehicle   2200 non-null   float64
# dtypes: float64(9), int64(2), str(1)
# memory usage: 206.4 KB

# %%
### Descriptive statistics for numerical columns

crime_rates.describe()
# Out:
#           year           pop  violent   murder     rape  robbery  assault  \
# count 2,200.00      2,200.00 2,200.00 2,200.00 2,200.00 2,200.00 2,200.00
# mean  1,981.50  4,609,092.06   369.86     6.38    26.86   115.55   221.07
# std      12.70  5,009,459.77   243.08     3.76    15.83    98.88   151.98
# min   1,960.00    226,167.00     9.50     0.20     0.80     1.90     3.60
# 25%   1,970.75  1,182,750.00   173.30     3.20    14.58    38.07   100.97
# 50%   1,981.50  3,187,500.00   320.90     5.70    25.40    93.85   190.75
# 75%   1,992.25  5,440,050.25   522.65     9.10    36.73   160.40   308.18
# max   2,003.00 35,484,453.00 1,244.30    20.30   102.20   684.00   785.70
#
#        property  burglary  larceny  vehicle
# count  2,200.00  2,200.00 2,200.00 2,200.00
# mean   3,736.73    965.01 2,412.48   359.23
# std    1,454.85    446.38   955.27   207.75
# min      573.10    182.60   293.30    48.30
# 25%    2,640.65    618.63 1,700.40   195.90
# 50%    3,815.75    910.45 2,495.15   324.45
# 75%    4,703.53  1,232.68 3,025.53   471.10
# max    7,996.00  2,906.70 5,106.10 1,571.10

# %%
### Customize the dataframe using our column names
crime_rates.columns = ['state', 'year', 'pop', 'violent', 'murder',
                       'rape', 'robbery', 'assault', 'property',
                       'burglary', 'larceny','vehicle']


## There is another way to do this where you can assign the column name to a list first. See if you can try both ways.
# Out:
#     state  year     pop  violent  murder  rape  robbery  assault  property  \
# 0  Alaska  1960  226167   104.30   10.20 20.80    28.30    45.10  1,544.90
# 1  Alaska  1961  234000    88.90   11.50 13.20    12.40    51.70  1,540.60
# 2  Alaska  1962  246000    91.50    4.50 18.70    13.80    54.50  1,564.60
# 3  Alaska  1963  248000   109.70    6.50 14.90    22.20    66.10  1,952.80
# 4  Alaska  1964  250000   150.00   10.40 22.40    21.20    96.00  2,016.00
#
#    burglary  larceny  vehicle
# 0    332.10   970.50   242.30
# 1    380.80   950.00   209.80
# 2    351.60   985.40   227.60
# 3    381.50 1,213.70   357.70
# 4    443.60 1,218.40   354.00

# %% [markdown]
# ## Data manipulation and analysis
# You can select rows with sepcific column value that you specify. Below select the state 'Alaska' and retrieve the rows with murder rate greater than 10.

# %%
alaska_crimes = crime_rates.loc[
    (crime_rates['state'] == 'Alaska') & (crime_rates['murder'] > 10)
]
alaska_crimes
# Out:
#      state  year     pop  violent  murder   rape  robbery  assault  property  \
# 0   Alaska  1960  226167   104.30   10.20  20.80    28.30    45.10  1,544.90
# 1   Alaska  1961  234000    88.90   11.50  13.20    12.40    51.70  1,540.60
# 4   Alaska  1964  250000   150.00   10.40  22.40    21.20    96.00  2,016.00
# 6   Alaska  1966  272000   150.40   12.90  19.50    36.00    82.00  2,635.30
# 8   Alaska  1968  277000   175.50   10.50  21.70    52.70    90.60  3,145.50
# 9   Alaska  1969  282000   221.30   10.60  29.40    67.40   113.80  3,658.90
# 10  Alaska  1970  302173   278.00   12.20  26.10    71.80   167.80  3,523.80
# 11  Alaska  1971  313000   355.30   13.40  43.50    67.10   231.30  3,809.30
# 14  Alaska  1974  337000   453.10   13.60  49.30    88.40   301.80  4,786.60
# 15  Alaska  1975  352000   539.80   12.20  44.60   129.50   353.40  5,656.80
# 16  Alaska  1976  382000   540.10   11.30  46.90   124.90   357.10  5,680.60
# 17  Alaska  1977  407000   443.20   10.80  51.60    96.80   284.00  5,454.80
# 18  Alaska  1978  403000   441.90   12.90  55.60    91.30   282.10  5,604.20
# 19  Alaska  1979  406000   491.10   13.30  71.90   109.60   296.30  5,712.60
# 21  Alaska  1981  412000   615.80   14.60 102.20   114.60   384.50  5,979.10
# 22  Alaska  1982  438000   623.70   18.50  85.40   133.80   386.10  5,588.80
# 23  Alaska  1983  479000   613.80   13.80 101.50    97.10   401.50  5,404.80
# 24  Alaska  1984  500000   621.60   11.60  91.60   109.40   409.00  5,493.60
# 27  Alaska  1987  525000   455.40   10.10  65.00    73.10   307.20  4,922.10
#
#     burglary  larceny  vehicle
# 0     332.10   970.50   242.30
# 1     380.80   950.00   209.80
# 4     443.60 1,218.40   354.00
# 6     593.00 1,600.70   441.50
# 8     747.30 1,915.90   482.30
# 9     870.60 2,196.80   591.50
# 10    789.90 2,182.50   551.30
# 11    848.60 2,438.00   522.70
# 14  1,166.80 2,972.10   647.80
# 15  1,214.50 3,522.40   919.90
# 16  1,218.10 3,656.80   805.80
# 17  1,331.70 3,369.80   753.30
# 18  1,339.20 3,603.50   661.50
# 19  1,383.30 3,713.30   616.00
# 21  1,329.90 3,958.70   690.50
# 22  1,188.10 3,806.40   594.30
# 23  1,194.20 3,566.80   643.80
# 24  1,236.80 3,628.00   628.80
# 27    970.10 3,465.70   486.30

# %% [markdown]
# #Index operator and attribute selection
# ## Index-based selection
# Pandas has its own indexing operators, `iloc` and `loc`.
# - `.iloc[ ]`: index(integer)-based selection that selects data based on its numerical position in the data
# - `.loc[ ]`: primarily label based
#
# &nbsp;
# **Indexing in pandas**
# - [start:stop:skip] #stop is exclusive [1:3] --> index 1 & 2
# - [1::2, :] #from the 2nd row all the way to the end every other row, and all the columns
# - [:, :3] #all rows, from the beginning to the 3rd column (0, 1, 2)

# %%
### Select first row of the crime_rates df

crime_rates.iloc[0]
# Out:
# state        Alaska
# year           1960
# pop          226167
# violent      104.30
# murder        10.20
# rape          20.80
# robbery       28.30
# assault       45.10
# property   1,544.90
# burglary     332.10
# larceny      970.50
# vehicle      242.30
# Name: 0, dtype: object

# %%
### Select all rows, first column

crime_rates.iloc[:, 0]
# Out:
# 0        Alaska
# 1        Alaska
# 2        Alaska
# 3        Alaska
# 4        Alaska
#          ...
# 2195    Wyoming
# 2196    Wyoming
# 2197    Wyoming
# 2198    Wyoming
# 2199    Wyoming
# Name: state, Length: 2200, dtype: str

# %% [markdown]
# The `:` operator from native Python is equivalent to "everything". When combined with other selectors, however, it can be used to indicate a range of values. For example, to select the 'state' column from just the first, second, and third row, we would do:

# %%
### Select the 'state' column from just the first, second, and third row

crime_rates.iloc[:3, 0]
# Out:
# 0    Alaska
# 1    Alaska
# 2    Alaska
# Name: state, dtype: str

# %% [markdown]
# ## Label-based selection
# `loc` operator is an attribute selection that is a label-based selection. The selection is based on the data index value, not its position.

# %%
### Select the year', 'state', and 'pop' columns by label

crime_rates.loc[:, ['year', 'state', 'pop']]
# Out:
#       year    state     pop
# 0     1960   Alaska  226167
# 1     1961   Alaska  234000
# 2     1962   Alaska  246000
# 3     1963   Alaska  248000
# 4     1964   Alaska  250000
# ...    ...      ...     ...
# 2195  1999  Wyoming  480000
# 2196  2000  Wyoming  493782
# 2197  2001  Wyoming  494423
# 2198  2002  Wyoming  498830
# 2199  2003  Wyoming  501242
#
# [2200 rows x 3 columns]

# %% [markdown]
# ## Simple data analysis
# Let's take a look at the crime rates in Alaska throughout the years.

# %%
### Select crimes data for state of Alaska


### Set the year as the index of the DataFrame

alaska = crime_rates.loc[crime_rates['state'] == 'Alaska'].copy()
alaska = alaska.set_index('year')
alaska.head()
# Out:
#        state     pop  violent  murder  rape  robbery  assault  property  \
# year
# 1960  Alaska  226167   104.30   10.20 20.80    28.30    45.10  1,544.90
# 1961  Alaska  234000    88.90   11.50 13.20    12.40    51.70  1,540.60
# 1962  Alaska  246000    91.50    4.50 18.70    13.80    54.50  1,564.60
# 1963  Alaska  248000   109.70    6.50 14.90    22.20    66.10  1,952.80
# 1964  Alaska  250000   150.00   10.40 22.40    21.20    96.00  2,016.00
#
#       burglary  larceny  vehicle
# year
# 1960    332.10   970.50   242.30
# 1961    380.80   950.00   209.80
# 1962    351.60   985.40   227.60
# 1963    381.50 1,213.70   357.70
# 1964    443.60 1,218.40   354.00

# %%
### Use .iloc to select all rows and all the columns about crime rates
### Use .plot.line() to create DataFrame (or Series) as lines
lines = alaska.iloc[:, 2:].plot.line(
    figsize=(12, 6), title='Alaska crime rates by year',
    xlabel='Year', ylabel='Reported crime rate'
)

# %% [markdown]
# # Class Exercise
# In class we will break up into different groups and work together to come up with solutions to your assigned question. After your group have finalize their solution, add it to the class notebook below. Remember to include everyone's name under the exercise.
#
# If you have questions or feedback for each other such as a different approach to the solution, create a new cell with your comments, questions, suggestion, code, etc... Let's work together to learn pandas.

# %% [markdown]
# ## **Class Exercise CL4.1**
# Filter the dataset for counts of robberies, bugarlies and murder cases in Alaska between the year of 1970 and 1979, inclusively. Which year had the highest number of crime cases for each of the three crime types?
#
# &nbsp;
# *Hint:*
# *   Use `&` to combine two conditions
# *   Use df[df['colname'].idxmax()] to get max value
# *   Use df.loc[df['colname1'].idxmax(), 'colname2'] to call for the row index that has the max value for colname1, and returns the colname2 value that corresponds to that row index.

# %%
# Your code

alaska_1970s = crime_rates.loc[
    (crime_rates['state'] == 'Alaska') & crime_rates['year'].between(1970, 1979),
    ['year', 'robbery', 'burglary', 'murder']
]
display(alaska_1970s)
peak_years = alaska_1970s.set_index('year').agg(['idxmax', 'max']).T
peak_years.columns = ['Year of highest rate', 'Highest rate']
display(peak_years)
# Out:
#     year  robbery  burglary  murder
# 10  1970    71.80    789.90   12.20
# 11  1971    67.10    848.60   13.40
# 12  1972    66.50    970.80    9.50
# 13  1973    67.00  1,167.30   10.00
# 14  1974    88.40  1,166.80   13.60
# 15  1975   129.50  1,214.50   12.20
# 16  1976   124.90  1,218.10   11.30
# 17  1977    96.80  1,331.70   10.80
# 18  1978    91.30  1,339.20   12.90
# 19  1979   109.60  1,383.30   13.30
#           Year of highest rate  Highest rate
# robbery               1,975.00        129.50
# burglary              1,979.00      1,383.30
# murder                1,974.00         13.60

# %% [markdown]
# ## **Class Exercise CL4.2**
# Which state had the highest number of vehicle crimes cases for the year 1982?

# %%
# Your code

crime_1982 = crime_rates.loc[crime_rates['year'] == 1982]
crime_1982.loc[crime_1982['vehicle'].idxmax(), ['state', 'year', 'vehicle']]
# Out:
# state      Massachuse
# year             1982
# vehicle        968.60
# Name: 814, dtype: object

# %% [markdown]
# ## **Class Exercise CL4.3**
# Create a line plot that display the number of crime cases for California for the year between 1980 and 2003, inclusively. For the line plot, the horizontal axis is year and vertical axis is the number of crime cases.
#
# *Hint:*
# * df.drop(['colname'], axis 1) can be used to drop a column. Axis 1 is used for columns and axis 0 is for rows.
# * See https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.line.html for info on how to use `df.plot.line`

# %%
# Your code

california = crime_rates.loc[
    (crime_rates['state'] == 'California') & crime_rates['year'].between(1980, 2003)
].set_index('year').drop(columns=['state', 'pop'])
california.plot.line(figsize=(12, 6), title='California crime rates, 1980-2003',
                     xlabel='Year', ylabel='Reported crime rate');

# %% [markdown]
# ## **Class Exercise CL4.4**
# Create a line plot that display the number of crime cases for Oregon between the year 1980 and 2000, inclusively. For the line plot, display the trend line to show only crimes cases under 1000 (where the number of crime cases is on the vertical axis) and the horizontal axis is year.

# %%
# Your code

oregon = crime_rates.loc[
    (crime_rates['state'] == 'Oregon') & crime_rates['year'].between(1980, 2000)
].set_index('year').drop(columns=['state', 'pop'])
# Mask individual rates at or above 1000 without joining lines across missing years.
oregon_below_1000 = oregon.where(oregon < 1000).dropna(axis=1, how='all')
oregon_below_1000.plot.line(
    figsize=(12, 6), title='Oregon crime rates below 1000, 1980-2000',
    xlabel='Year', ylabel='Reported crime rate', ylim=(0, 1000));

# %% [markdown]
# ## **Class Exercise CL4.5**
# Create a line plot that display the number of crime cases for Colorado for all the years and excluding the data for burglary, larceny, and property.

# %%
# Your code

colorado = crime_rates.loc[crime_rates['state'] == 'Colorado'].set_index('year')
colorado.drop(columns=['state', 'pop', 'burglary', 'larceny', 'property']).plot.line(
    figsize=(12, 6), title='Selected Colorado crime rates by year',
    xlabel='Year', ylabel='Reported crime rate');
